# %%
git checkout -b new-feature main
# Out:
# 运行具有“Python 3.12.9”的单元格需要ipykernel包。
#
# 运行以下命令，将 "ipykernel" 安装到 Python 环境中。
#
# 命令: "d:/python.exe -m pip install ipykernel -U --user --force-reinstall"
